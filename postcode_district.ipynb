# %%
import pandas as pd
import glob
import os
import numpy as np
import datetime

# %%
postcode = pd.read_csv(r"E:\Diabetes\Datasets\postcodes\postcode_subset.csv")

# %%
postcode
# Out:
#       Postcode  Eastings  Northings
# 0      BH1 1AA    409722      92041
# 1      BH1 1AF    409181      91523
# 2      BH1 1AH    409265      91464
# 3      BH1 1AJ    409162      92265
# 4      BH1 1AL    409284      91366
# 5      BH1 1AN    409437      91439
# 6      BH1 1AQ    409442      91597
# 7      BH1 1AR    409079      91486
# 8      BH1 1AT    409270      91630
# 9      BH1 1AU    408759      91267
# 10     BH1 1BA    408678      91201
# 11     BH1 1BB    408701      91210
# 12     BH1 1BL    408643      91233
# 13     BH1 1BN    408643      91233
# 14     BH1 1BZ    408737      91281
# 15     BH1 1DA    408740      91301
# 16     BH1 1DF    408777      91311
# 17     BH1 1DJ    408785      91309
# 18     BH1 1DL    408763      91333
# 19     BH1 1DP    408804      91337
# 20     BH1 1DR    408675      91184
# 21     BH1 1DS    408734      91209
# 22     BH1 1DT    408782      91268
# 23     BH1 1DU    408637      91195
# 24     BH1 1DW    408798      91347
# ...

# %%
postcode['District'] = postcode['Postcode'].str[:4]

# %%
postcode
# Out:
#       Postcode  Eastings  Northings District
# 0      BH1 1AA    409722      92041     BH1
# 1      BH1 1AF    409181      91523     BH1
# 2      BH1 1AH    409265      91464     BH1
# 3      BH1 1AJ    409162      92265     BH1
# 4      BH1 1AL    409284      91366     BH1
# 5      BH1 1AN    409437      91439     BH1
# 6      BH1 1AQ    409442      91597     BH1
# 7      BH1 1AR    409079      91486     BH1
# 8      BH1 1AT    409270      91630     BH1
# 9      BH1 1AU    408759      91267     BH1
# 10     BH1 1BA    408678      91201     BH1
# 11     BH1 1BB    408701      91210     BH1
# 12     BH1 1BL    408643      91233     BH1
# 13     BH1 1BN    408643      91233     BH1
# 14     BH1 1BZ    408737      91281     BH1
# 15     BH1 1DA    408740      91301     BH1
# 16     BH1 1DF    408777      91311     BH1
# 17     BH1 1DJ    408785      91309     BH1
# 18     BH1 1DL    408763      91333     BH1
# 19     BH1 1DP    408804      91337     BH1
# ...

# %%
postcode.to_csv(r"E:\Diabetes\Datasets\postcodes\postcode_district.csv")

# %%
postcode = pd.read_csv(r"E:\Diabetes\Datasets\postcodes\all_postcodes_cut.csv")

# %%
postcode['District'] = postcode['Postcode'].str[:4]

# %%
postcode
# Out:
#         Postcode  Eastings  Northings District
# 0        AB101AB    394235     806529     AB10
# 1        AB101AF    394181     806429     AB10
# 2        AB101AG    394230     806469     AB10
# 3        AB101AH    394371     806359     AB10
# 4        AB101AL    394326     806522     AB10
# 5        AB101AN    394367     806541     AB10
# 6        AB101AP    394309     806459     AB10
# 7        AB101AQ    394371     806359     AB10
# 8        AB101AR    394371     806359     AB10
# 9        AB101AS    394198     806385     AB10
# 10       AB101AU    394264     806318     AB10
# 11       AB101AW    394226     806282     AB10
# 12       AB101AX    394181     806429     AB10
# 13       AB101BA    394141     806457     AB10
# 14       AB101BB    394223     806262     AB10
# 15       AB101BD    394261     806288     AB10
# 16       AB101BF    394187     806225     AB10
# 17       AB101BJ    393602     806136     AB10
# 18       AB101BL    394216     806398     AB10
# ...

# %%
postcode.to_csv(r"E:\Diabetes\Datasets\postcodes\postcode_district_all_ne.csv")
