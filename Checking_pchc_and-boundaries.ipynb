# %% [markdown]
# # Import the relevant libraries

# %%
import numpy as np
from matplotlib.pyplot import *
import pandas as pd
from scipy import stats
import glob
import os

# %% [markdown]
# ## Read in the LADUA lookup

# %%
LADUA = pd.read_csv(r'/Users/annalisasheehan/Documents/Imperial-Diabetes/LAD01_LAD11_LU.csv')
LADUA = LADUA.set_index('LAD01CD')

# %%
LADUA
# Out:
#                               LAD01NM    LAD11CD LAD11CDO  \
# LAD01CD
# 00EB                       Hartlepool  E06000001     00EB
# 00EC                    Middlesbrough  E06000002     00EC
# 00EE             Redcar and Cleveland  E06000003     00EE
# 00EF                 Stockton-on-Tees  E06000004     00EF
# 00EH                       Darlington  E06000005     00EH
# 00ET                           Halton  E06000006     00ET
# 00EU                       Warrington  E06000007     00EU
# 00EX            Blackburn with Darwen  E06000008     00EX
# 00EY                        Blackpool  E06000009     00EY
# 00FA      Kingston upon Hull, City of  E06000010     00FA
# 00FB         East Riding of Yorkshire  E06000011     00FB
# 00FC          North East Lincolnshire  E06000012     00FC
# 00FD               North Lincolnshire  E06000013     00FD
# 00FF                             York  E06000014     00FF
# 00FK                            Derby  E06000015     00FK
# ...

# %% [markdown]
# ## Read in the pchc data for the two different boundaries

# %%
pchc2001 = pd.read_csv(r'/Users/annalisasheehan/Documents/Imperial-Diabetes/Spatial_join_2001.csv')
pchc2001 = pchc2001.rename(columns={'ons_label': 'ons_label_sj', 'POPULATION': 'pc2001pop', 'HOUSEHOLDS': 'pc2001house', 'Join_Count': 'JC_2001'})
pchc2001 = pchc2001.set_index('ons_label_sj')

pchc2014 = pd.read_csv(r'/Users/annalisasheehan/Documents/Imperial-Diabetes/Spatial_join_2014.csv')
pchc2014 = pchc2014.rename(columns={'lad14cd': 'lad14cd_sj', 'POPULATION': 'pc2014pop', 'HOUSEHOLDS': 'pc2014house', 'Join_Count': 'JC_2014'})
pchc2014 = pchc2014.set_index('lad14cd_sj')

# %%
pchc2001
# Out:
#               JC_2001                      name  pc2001pop  pc2001house
# ons_label_sj
# 15UE             3060            North Cornwall      80438           10
# 18UD             2878                 Mid Devon      69858            3
# 19UH             3437               West Dorset      92383            8
# 23UC             2763                  Cotswold      80370            3
# 33UB             3576                 Breckland     121503           24
# 33UF             3814             North Norfolk      98487           12
# 32UC             4389              East Lindsey     130442           14
# 00FD             4037     North Lincolnshire UA     152933            6
# 00FB             8425  East Riding of Yorkshire     314082            5
# 36UE             2173             Richmondshire      47031            3
# 36UG             2929               Scarborough     106188            9
# 15UD             3210                   Kerrier      92490            3
# ...

# %%
LADUA2001 = LADUA.merge(pchc2001, how= 'left', left_index=True, right_index=True)

# %%
LADUA2001
# Out:
#                      LAD01NM    LAD11CD LAD11CDO                 LAD11NM  \
# 00AA          City of London  E09000001     00AA          City of London
# 00AB    Barking and Dagenham  E09000002     00AB    Barking and Dagenham
# 00AC                  Barnet  E09000003     00AC                  Barnet
# 00AD                  Bexley  E09000004     00AD                  Bexley
# 00AE                   Brent  E09000005     00AE                   Brent
# 00AF                 Bromley  E09000006     00AF                 Bromley
# 00AG                  Camden  E09000007     00AG                  Camden
# 00AH                 Croydon  E09000008     00AH                 Croydon
# 00AJ                  Ealing  E09000009     00AJ                  Ealing
# 00AK                 Enfield  E09000010     00AK                 Enfield
# 00AL               Greenwich  E09000011     00AL               Greenwich
# 00AM                 Hackney  E09000012     00AM                 Hackney
# ...

# %%
LADUA2001.reset_index(level=0, inplace=True)

LADUA2001 = LADUA2001.set_index('LAD11CD')

# %%
LADUA2014 = LADUA2001.merge(pchc2014, how= 'left', left_index=True, right_index=True)

# %%
LADUA2001
# Out:
#           index                 LAD01NM LAD11CDO                 LAD11NM  \
# LAD11CD
# E09000001  00AA          City of London     00AA          City of London
# E09000002  00AB    Barking and Dagenham     00AB    Barking and Dagenham
# E09000003  00AC                  Barnet     00AC                  Barnet
# E09000004  00AD                  Bexley     00AD                  Bexley
# E09000005  00AE                   Brent     00AE                   Brent
# E09000006  00AF                 Bromley     00AF                 Bromley
# E09000007  00AG                  Camden     00AG                  Camden
# E09000008  00AH                 Croydon     00AH                 Croydon
# E09000009  00AJ                  Ealing     00AJ                  Ealing
# E09000010  00AK                 Enfield     00AK                 Enfield
# E09000011  00AL               Greenwich     00AL               Greenwich
# E09000012  00AM                 Hackney     00AM                 Hackney
# ...

# %%
LADUA2014.to_csv(r'/Users/annalisasheehan/Documents/Imperial-Diabetes/Spatial_join_00_14_v3.csv')

# %% [markdown]
# # Checking clipped and full extent boundaries

# %%
pchc2001 = pd.read_csv(r'/Users/annalisasheehan/Documents/Imperial-Diabetes/Spatial_join_2001.csv')
pchc2001 = pchc2001.rename(columns={'ons_label': 'ons_label_sj', 'POPULATION': 'pc2001pop', 'HOUSEHOLDS': 'pc2001house', 'Join_Count': 'JC_2001'})
pchc2001 = pchc2001.set_index('ons_label_sj')

pchc2014 = pd.read_csv(r'/Users/annalisasheehan/Documents/Imperial-Diabetes/Spatial_join_2014_C.csv')
pchc2014 = pchc2014.rename(columns={'lad14cd': 'lad14cd_sj', 'POPULATION': 'pc2014pop', 'HOUSEHOLDS': 'pc2014house', 'Join_Count': 'JC_2014'})
pchc2014 = pchc2014.set_index('lad14cd_sj')

# %%
pchc2014
# Out:
#             Join_Count_2014_C                       lad14nm  \
# lad14cd_sj
# E06000001                2164                    Hartlepool
# E06000002                3168                 Middlesbrough
# E06000003                3496          Redcar and Cleveland
# E06000004                4324              Stockton-on-Tees
# E06000005                2307                    Darlington
# E06000006                2309                        Halton
# E06000007                4166                    Warrington
# E06000008                2589         Blackburn with Darwen
# E06000009                2985                     Blackpool
# E06000010                4716   Kingston upon Hull, City of
# E06000011                8425      East Riding of Yorkshire
# E06000012                3738       North East Lincolnshire
# E06000013                4037            North Lincolnshire
# E06000014                4246                          York
# ...

# %%
LADUA2001 = LADUA.merge(pchc2001, how= 'left', left_index=True, right_index=True)

# %%
LADUA2001.reset_index(level=0, inplace=True)

LADUA2001 = LADUA2001.set_index('LAD11CD')

# %%
LADUA2014 = LADUA2001.merge(pchc2014, how= 'left', left_index=True, right_index=True)

# %%
LADUA2014
# Out:
#           index                       LAD01NM LAD11CDO  \
# E06000001  00EB                    Hartlepool     00EB
# E06000002  00EC                 Middlesbrough     00EC
# E06000003  00EE          Redcar and Cleveland     00EE
# E06000004  00EF              Stockton-on-Tees     00EF
# E06000005  00EH                    Darlington     00EH
# E06000006  00ET                        Halton     00ET
# E06000007  00EU                    Warrington     00EU
# E06000008  00EX         Blackburn with Darwen     00EX
# E06000009  00EY                     Blackpool     00EY
# E06000010  00FA   Kingston upon Hull, City of     00FA
# E06000011  00FB      East Riding of Yorkshire     00FB
# E06000012  00FC       North East Lincolnshire     00FC
# E06000013  00FD            North Lincolnshire     00FD
# E06000014  00FF                          York     00FF
# E06000015  00FK                         Derby     00FK
# E06000016  00FN                     Leicester     00FN
# ...

# %%
LADUA2014.to_csv(r'/Users/annalisasheehan/Documents/Imperial-Diabetes/Spatial_join_00_14_clipped.csv')
