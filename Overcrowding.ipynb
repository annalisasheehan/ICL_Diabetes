# %%
import pandas as pd
import glob
import os
import numpy as np
import datetime

# %%
overcrowding = pd.read_csv(r"S:\Projects\SAHSU_Share\Diabetes\Datasets\Overcrowding\CS052 - Tenure and persons per room by accommodation type 2001.csv")

# %%
overcrowding
# Out:
#           super output areas - middle layer  CatA  CatB  CatC  CatD  \
# 0                E02002559 : Darlington 001  2151   492     6     0
# 1                E02002560 : Darlington 002  1701   704     3     3
# 2                E02002561 : Darlington 003  1766   683    19     3
# 3                E02002562 : Darlington 004  2078   720    27     9
# 4                E02002563 : Darlington 005  1691   662    13     6
# 5                E02002564 : Darlington 006  2816  1085    55     9
# 6                E02002565 : Darlington 007  2011   577     9     6
# 7                E02002566 : Darlington 008  2248   685    24    21
# 8                E02002567 : Darlington 009  1989   787    46     9
# 9                E02002568 : Darlington 010  1932   376     6     9
# 10               E02002569 : Darlington 011  3197   679     6     3
# 11               E02002570 : Darlington 012  2368   850    39    18
# 12               E02002571 : Darlington 013  1535   637    37     3
# ...

# %%
overcrowding['MSOA01']= overcrowding['super output areas - middle layer'].str[:9]

# %%
overcrowding['MSOA01nm']= overcrowding['super output areas - middle layer'].str[12:]

# %%
overcrowding.to_csv(r"S:\Projects\SAHSU_Share\Diabetes\Datasets\Overcrowding\CS052_cd.csv")
